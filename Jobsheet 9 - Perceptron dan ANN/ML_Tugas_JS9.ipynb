# %% [markdown]
# <a href="https://colab.research.google.com/github/NadilaAmaliaaa/MACHINE_LEARNING/blob/main/Jobsheet%209%20-%20Perceptron%20dan%20ANN/ML_Tugas_JS9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Nama: Nadila Amalia Pribadi
# ### Kelas: TI-3F / 19
# ### NIM: 2241720114
#
# ## Tugas Jobsheet 9 Machine Learning

# %% [markdown]
# ### Import Library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import keras
import tensorflow

from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import regularizers

# %% [markdown]
# ### Menyiapkan Dataset MNIST

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
fig, ax = plt.subplots(nrows = 5, ncols = 10, figsize=(8,4), subplot_kw={'xticks': [], 'yticks': []})
for row in range(0,5):
    for col in range(0,10):
        myid = (10*row) + col # (ncols*rows) + cols

        ax[row,col].imshow( x_train[myid], cmap=plt.cm.binary ) # W,H,C
        ax[row,col].axis('off')

plt.suptitle("Gambar data MNIST", size=20, color="#000000")

plt.show()

# %% [markdown]
# ### Informasi Dataset

# %%
print("bentuk data: ",x_train.shape)
print("nilai max data: ",x_train[0].max())
# Out:
# bentuk data:  (60000, 28, 28)
# nilai max data:  255

# %% [markdown]
# ### Praproses dan Normalisasi Data

# %%
x_train = x_train.reshape(-1, 28*28)
x_train = x_train.astype('float32')/255

x_test = x_test.reshape(-1, 28*28)
x_test = x_test.astype('float32')/255

print("hasil: ",x_train.shape)
print("nilai max data: ",x_train[0].max())
# Out:
# hasil:  (60000, 784)
# nilai max data:  1.0

# %% [markdown]
# ### Pemodelan ANN

# %%
# ubah bentuk label menjadi kategorical untuk digunakan tensorflow nantinya
y_train = tensorflow.keras.utils.to_categorical(y_train , num_classes=10)
y_test = tensorflow.keras.utils.to_categorical(y_test , num_classes=10)

# %%
# pembuatan hidden layer
from tensorflow.keras.layers import MaxPooling2D,Conv2D,Input,Add,MaxPool2D,Flatten,AveragePooling2D,Dense,BatchNormalization,ZeroPadding2D,Activation,Concatenate,UpSampling2D
from tensorflow.keras.models import Model

nn_model = Sequential()
nn_model.add(Dense(35, input_dim=784, activation='relu'))
nn_model.add(Dropout(0.3))
nn_model.add(Dense(10, activation='softmax'))
print(nn_model)
# Out:
# <Sequential name=sequential_3, built=True>
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
nn_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = nn_model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7738 - loss: 0.7454
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9036 - loss: 0.3249
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9150 - loss: 0.2838
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9235 - loss: 0.2537
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9268 - loss: 0.2404
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9301 - loss: 0.2316
# Epoch 7/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9311 - loss: 0.2171
# Epoch 8/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9349 - loss: 0.2082
# Epoch 9/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9372 - loss: 0.2053
# Epoch 10/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9380 - loss: 0.1967
# Epoch 11/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9390 - loss: 0.1919
# Epoch 12/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9417 - loss: 0.1895
# Epoch 13/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9393 - loss: 0.1880
# Epoch 14/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9406 - loss: 0.1896
# Epoch 15/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9394 - loss: 0.1850
# Epoch 16/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9408 - loss: 0.1813
# Epoch 17/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9414 - loss: 0.1860
# Epoch 18/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9444 - loss: 0.1744
# Epoch 19/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9454 - loss: 0.1690
# Epoch 20/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9442 - loss: 0.1721
# Epoch 21/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9455 - loss: 0.1690
# Epoch 22/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9466 - loss: 0.1699
# Epoch 23/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9451 - loss: 0.1672
# Epoch 24/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9448 - loss: 0.1678
# Epoch 25/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9468 - loss: 0.1623
# Epoch 26/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9460 - loss: 0.1614
# Epoch 27/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9467 - loss: 0.1632
# Epoch 28/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9467 - loss: 0.1639
# Epoch 29/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9459 - loss: 0.1660
# Epoch 30/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9486 - loss: 0.1610
# Epoch 31/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9484 - loss: 0.1597
# Epoch 32/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9490 - loss: 0.1519
# Epoch 33/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9492 - loss: 0.1557
# Epoch 34/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9487 - loss: 0.1532
# Epoch 35/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9498 - loss: 0.1502
# Epoch 36/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9503 - loss: 0.1511
# Epoch 37/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9514 - loss: 0.1498
# Epoch 38/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9487 - loss: 0.1570
# Epoch 39/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9496 - loss: 0.1517
# Epoch 40/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9521 - loss: 0.1440
# Epoch 41/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9483 - loss: 0.1556
# Epoch 42/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9500 - loss: 0.1480
# Epoch 43/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9517 - loss: 0.1442
# Epoch 44/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9528 - loss: 0.1447
# Epoch 45/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9520 - loss: 0.1458
# Epoch 46/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9514 - loss: 0.1467
# Epoch 47/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9516 - loss: 0.1480
# Epoch 48/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9517 - loss: 0.1487
# Epoch 49/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9522 - loss: 0.1432
# Epoch 50/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9524 - loss: 0.1414

# %% [markdown]
# ### Evaluasi

# %%
#Akurasi terbaik
best_accuracy = max(history.history['accuracy'])
best_epoch = history.history['accuracy'].index(best_accuracy) + 1
print("Akurasi terbaik:", best_accuracy, "pada epoch:", best_epoch)

# Visualisasi loss (kerugian)
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Loss (Kerugian)')
plt.title('Loss (Kerugian) per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Visualisasi akurasi
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Akurasi')
plt.title('Akurasi per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Akurasi')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Akurasi terbaik: 0.9522333145141602 pada epoch: 50

# %%
# Menghitung akurasi model pada data pengujian menggunakan prediksi yang dihasilkan sebelumnya
from sklearn.metrics import accuracy_score
y_prob = nn_model.predict(x_test)
y_pred = y_prob.argmax(axis=1)
y_test = np.argmax(y_test, axis=1)
accuracy_score(y_test,y_pred)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 0.9653

# %% [markdown]
# ### Confussion Matrix

# %%
from sklearn.metrics import confusion_matrix  # for evaluating results
import seaborn as sn

confusion_array = confusion_matrix(y_true = y_test,y_pred = y_pred)
df_cm = pd.DataFrame(confusion_array, range(10), range(10))
plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 10})
# Out:
# <Axes: >
